# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy import stats
from scipy.stats import norm, skew

# %%
DAGUCARD06_header_list=['년도','년월','운행_일자','요일_구분','시간대'
                          ,'이용자_유형_코드','교통수단_코드','정산사_ID','정산_지역_코드','교통수단_구분_코드'
                          ,'노선_ID','정류장_ID','시도_코드','시군구_코드','이용_지역_코드'
                          ,'발생_통행인원','도착_통행인원','발생_통행건수','도착_통행건수','발생_이용거리'
                          ,'도착_이용거리','발생_소요시간','도착_소요시간']

DAGUCARD06=pd.read_csv('DAGUCARD06.csv',names=DAGUCARD06_header_list)

# %%
# 이용_지역_코드, 시군구_코드 리스트로 만들어둠.
dong_code_list=DAGUCARD06.이용_지역_코드.unique()
gu_code_list=DAGUCARD06.시군구_코드.unique()
city_code_list=DAGUCARD06.시도_코드.unique()

# %%
# 출근_통행인원
def go_personnel_city(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday = DAGUCARD06_2019_before_weekday_tmp.sum()
    DAGUCARD06_2019_before_weekday_list_city.append(DAGUCARD06_2019_before_weekday/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend = DAGUCARD06_2019_before_weekend_tmp.sum()
    DAGUCARD06_2019_before_weekend_list_city.append(DAGUCARD06_2019_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday = DAGUCARD06_2019_after_weekday_tmp.sum()
    DAGUCARD06_2019_after_weekday_list_city.append(DAGUCARD06_2019_after_weekday/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend = DAGUCARD06_2019_after_weekend_tmp.sum()
    DAGUCARD06_2019_after_weekend_list_city.append(DAGUCARD06_2019_after_weekend/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday = DAGUCARD06_2020_before_weekday_tmp.sum()
    DAGUCARD06_2020_before_weekday_list_city.append(DAGUCARD06_2020_before_weekday/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend = DAGUCARD06_2020_before_weekend_tmp.sum()
    DAGUCARD06_2020_before_weekend_list_city.append(DAGUCARD06_2020_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday = DAGUCARD06_2020_after_weekday_tmp.sum()
    DAGUCARD06_2020_after_weekday_list_city.append(DAGUCARD06_2020_after_weekday/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend = DAGUCARD06_2020_after_weekend_tmp.sum()
    DAGUCARD06_2020_after_weekend_list_city.append(DAGUCARD06_2020_after_weekend/14)

# %%
# 일과_통행인원
def work_personnel_city(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday = DAGUCARD06_2019_before_weekday_tmp.sum()
    DAGUCARD06_2019_before_weekday_list_city.append(DAGUCARD06_2019_before_weekday/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend = DAGUCARD06_2019_before_weekend_tmp.sum()
    DAGUCARD06_2019_before_weekend_list_city.append(DAGUCARD06_2019_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday = DAGUCARD06_2019_after_weekday_tmp.sum()
    DAGUCARD06_2019_after_weekday_list_city.append(DAGUCARD06_2019_after_weekday/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend = DAGUCARD06_2019_after_weekend_tmp.sum()
    DAGUCARD06_2019_after_weekend_list_city.append(DAGUCARD06_2019_after_weekend/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday = DAGUCARD06_2020_before_weekday_tmp.sum()
    DAGUCARD06_2020_before_weekday_list_city.append(DAGUCARD06_2020_before_weekday/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend = DAGUCARD06_2020_before_weekend_tmp.sum()
    DAGUCARD06_2020_before_weekend_list_city.append(DAGUCARD06_2020_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday = DAGUCARD06_2020_after_weekday_tmp.sum()
    DAGUCARD06_2020_after_weekday_list_city.append(DAGUCARD06_2020_after_weekday/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend = DAGUCARD06_2020_after_weekend_tmp.sum()
    DAGUCARD06_2020_after_weekend_list_city.append(DAGUCARD06_2020_after_weekend/14)

# %%
# 퇴근_통행인원
def back_personnel_city(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday_arrival = DAGUCARD06_2019_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekday_arrival_list_city.append(DAGUCARD06_2019_before_weekday_arrival/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend_arrival = DAGUCARD06_2019_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekend_arrival_list_city.append(DAGUCARD06_2019_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday_arrival = DAGUCARD06_2019_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekday_arrival_list_city.append(DAGUCARD06_2019_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend_arrival = DAGUCARD06_2019_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekend_arrival_list_city.append(DAGUCARD06_2019_after_weekend_arrival/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday_arrival = DAGUCARD06_2020_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekday_arrival_list_city.append(DAGUCARD06_2020_before_weekday_arrival/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend_arrival = DAGUCARD06_2020_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekend_arrival_list_city.append(DAGUCARD06_2020_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday_arrival = DAGUCARD06_2020_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekday_arrival_list_city.append(DAGUCARD06_2020_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시도_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend_arrival = DAGUCARD06_2020_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekend_arrival_list_city.append(DAGUCARD06_2020_after_weekend_arrival/14)

# %%
for i in city_code_list:
    go_personnel_city(i)
    work_personnel_city(i)
    back_personnel_city(i)

# %%
y_go_weekday_values_city_rate_vs2020 = []
y_go_weekend_values_city_rate_vs2020 = []
y_work_weekday_values_city_rate_vs2020 = []
y_work_weekend_values_city_rate_vs2020 = []
y_back_weekday_values_city_rate_vs2020 = []
y_back_weekend_values_city_rate_vs2020 = []
    
y_go_weekday_values_city_rate_vs2019 = []
y_go_weekend_values_city_rate_vs2019 = []
y_work_weekday_values_city_rate_vs2019 = []
y_work_weekend_values_city_rate_vs2019 = []
y_back_weekday_values_city_rate_vs2019 = []
y_back_weekend_values_city_rate_vs2019 = []

for i in range(len(city_code_list)):
#for i in range(4):

#     print(dong_code_list[i],"\n")
#     print("2019년 일일 발생통행량 \n")
#     print("1월 1일부터 2월 17일까지 평일: ",round(DAGUCARD06_2019_before_weekday_start_list[i]/34),"\n")
#     print("1월 1일부터 2월 17일까지 주말: ",round(DAGUCARD06_2019_before_weekend_start_list[i]/14),"\n")
#     print("2월 18일부터 4월 6일까지 평일: ",round(DAGUCARD06_2019_after_weekday_start_list[i]/35),"\n")
#     print("2월 18일부터 4월 6일까지 주말: ",round(DAGUCARD06_2019_after_weekend_start_list[i]/13),"\n")
    
#     print("2020년 일일 발생통행량 \n")
#     print("1월 1일부터 2월 17일까지 평일: ",round(DAGUCARD06_2020_before_weekday_start_list[i]/34),"\n")
#     print("1월 1일부터 2월 17일까지 주말: ",round(DAGUCARD06_2020_before_weekend_start_list[i]/14),"\n")
#     print("2월 18일부터 4월 6일까지 평일: ",round(DAGUCARD06_2020_after_weekday_start_list[i]/35),"\n")
#     print("2월 18일부터 4월 6일까지 주말: ",round(DAGUCARD06_2020_after_weekend_start_list[i]/14),"\n")
#     print("\n")
#     print("2019년 일일 도착통행량 \n")
#     print("1월 1일부터 2월 17일까지 평일: ",round(DAGUCARD06_2019_before_weekday_arrival_list[i]/34),"\n")
#     print("1월 1일부터 2월 17일까지 주말: ",round(DAGUCARD06_2019_before_weekend_arrival_list[i]/14),"\n")
#     print("2월 18일부터 4월 6일까지 평일: ",round(DAGUCARD06_2019_after_weekday_arrival_list[i]/35),"\n")
#     print("2월 18일부터 4월 6일까지 주말: ",round(DAGUCARD06_2019_after_weekend_arrival_list[i]/13),"\n")
    
#     print("2020년 일일 도착통행량 \n")
#     print("1월 1일부터 2월 17일까지 평일: ",round(DAGUCARD06_2020_before_weekday_arrival_list[i]/34),"\n")
#     print("1월 1일부터 2월 17일까지 주말: ",round(DAGUCARD06_2020_before_weekend_arrival_list[i]/14),"\n")
#     print("2월 18일부터 4월 6일까지 평일: ",round(DAGUCARD06_2020_after_weekday_arrival_list[i]/35),"\n")
#     print("2월 18일부터 4월 6일까지 주말: ",round(DAGUCARD06_2020_after_weekend_arrival_list[i]/14),"\n")
#     print("-"*30)

    
    y_go_weekday_values_city = []
    y_go_weekend_values_city = []
    y_work_weekday_values_city = []
    y_work_weekend_values_city = []
    y_back_weekday_values_city = []
    y_back_weekend_values_city = []
    
    

    # 평일 출근
    y_go_weekday_values_city.append(DAGUCARD06_2019_before_weekday_start_list_city[i])
    y_go_weekday_values_city.append(DAGUCARD06_2019_after_weekday_start_list_city[i])
    y_go_weekday_values_city.append(DAGUCARD06_2020_before_weekday_start_list_city[i])
    y_go_weekday_values_city.append(DAGUCARD06_2020_after_weekday_start_list_city[i])
    
    # 주말 출근
    y_go_weekend_values_city.append(DAGUCARD06_2019_before_weekend_start_list_city[i])
    y_go_weekend_values_city.append(DAGUCARD06_2019_after_weekend_start_list_city[i])
    y_go_weekend_values_city.append(DAGUCARD06_2020_before_weekend_start_list_city[i])
    y_go_weekend_values_city.append(DAGUCARD06_2020_after_weekend_start_list_city[i])
    
    # 평일 일과
    y_work_weekday_values_city.append(DAGUCARD06_2019_before_weekday_list_city[i])
    y_work_weekday_values_city.append(DAGUCARD06_2019_after_weekday_list_city[i])
    y_work_weekday_values_city.append(DAGUCARD06_2020_before_weekday_list_city[i])
    y_work_weekday_values_city.append(DAGUCARD06_2020_after_weekday_list_city[i])
    
    # 주말 일과
    y_work_weekend_values_city.append(DAGUCARD06_2019_before_weekend_list_city[i])
    y_work_weekend_values_city.append(DAGUCARD06_2019_after_weekend_list_city[i])
    y_work_weekend_values_city.append(DAGUCARD06_2020_before_weekend_list_city[i])
    y_work_weekend_values_city.append(DAGUCARD06_2020_after_weekend_list_city[i])
    
    # 평일 퇴근
    y_back_weekday_values_city.append(DAGUCARD06_2019_before_weekday_arrival_list_city[i])
    y_back_weekday_values_city.append(DAGUCARD06_2019_after_weekday_arrival_list_city[i])
    y_back_weekday_values_city.append(DAGUCARD06_2020_before_weekday_arrival_list_city[i])
    y_back_weekday_values_city.append(DAGUCARD06_2020_after_weekday_arrival_list_city[i])
    
    # 주말 퇴근
    y_back_weekend_values_city.append(DAGUCARD06_2019_before_weekend_arrival_list_city[i])
    y_back_weekend_values_city.append(DAGUCARD06_2019_after_weekend_arrival_list_city[i])
    y_back_weekend_values_city.append(DAGUCARD06_2020_before_weekend_arrival_list_city[i])
    y_back_weekend_values_city.append(DAGUCARD06_2020_after_weekend_arrival_list_city[i])
    
    figure, ((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows = 2, ncols = 3)
    figure.set_size_inches(24,20)
    
    label=['19.01.01~19.02.17','19.02.18~19.04.06','20.01.01~20.02.17','20.02.18~20.04.06']
    index=np.arange(len(label))
   
    
    # 평일 출근
    ax1.bar(index,y_go_weekday_values_city)
    ax1.set_title('{} Weekday_go_to_work'.format(city_code_list[i]))
    ax1.set_xticks([0,1,2,3])
    ax1.set_xticklabels(label)
    ax1.legend()
    
     # 평일 일과
    ax2.bar(index,y_work_weekday_values_city)
    ax2.set_title('{} Weekday_work'.format(city_code_list[i]))
    ax2.set_xticks([0,1,2,3])
    ax2.set_xticklabels(label)
    ax2.legend()
    
     # 평일 퇴근
    ax3.bar(index,y_back_weekday_values_city)
    ax3.set_title('{} Weekday_off_work'.format(city_code_list[i]))
    ax3.set_xticks([0,1,2,3])
    ax3.set_xticklabels(label)
    ax3.legend()
    
     # 주말 출근
    ax4.bar(index,y_go_weekend_values_city)
    ax4.set_title('{} Weekend_go_to_work'.format(city_code_list[i]))
    ax4.set_xticks([0,1,2,3])
    ax4.set_xticklabels(label)
    ax4.legend()
    
    # 주말 일과
    ax5.bar(index,y_work_weekend_values_city)
    ax5.set_title('{} Weekend_work'.format(city_code_list[i]))
    ax5.set_xticks([0,1,2,3])
    ax5.set_xticklabels(label)
    ax5.legend()    
   
    # 주말 퇴근
    ax6.bar(index,y_back_weekend_values_city)
    ax6.set_title('{} Weekend_off_work'.format(city_code_list[i]))
    ax6.set_xticks([0,1,2,3])
    ax6.set_xticklabels(label)
    ax6.legend()
    #plt.savefig('{}_출근_일과_퇴근.png'.format(city_code_list[i]))
    
    
    
    
    
    print(y_go_weekday_values_city[3]/y_go_weekday_values_city[1])
    
    # 평일 출근 
    # vs 2019
    y_go_weekday_values_city_rate_vs2019.append(y_go_weekday_values_city[3]/y_go_weekday_values_city[1])
    # vs 2020
    y_go_weekday_values_city_rate_vs2020.append(y_go_weekday_values_city[3]/y_go_weekday_values_city[2])

    # 평일 일과
    # vs 2019
    y_work_weekday_values_city_rate_vs2019.append(y_work_weekday_values_city[3]/y_work_weekday_values_city[1])
    # vs 2020
    y_work_weekday_values_city_rate_vs2020.append(y_work_weekday_values_city[3]/y_work_weekday_values_city[2])
    
    # 평일 퇴근
    # vs 2019
    y_back_weekday_values_city_rate_vs2019.append(y_back_weekday_values_city[3]/y_back_weekday_values_city[1])
    # vs 2020
    y_back_weekday_values_city_rate_vs2020.append(y_back_weekday_values_city[3]/y_back_weekday_values_city[2])
    
    # 주말 출근
    # vs 2019
    y_go_weekend_values_city_rate_vs2019.append(y_go_weekend_values_city[3]/y_go_weekend_values_city[1])
    # vs 2020
    y_go_weekend_values_city_rate_vs2020.append(y_go_weekend_values_city[3]/y_go_weekend_values_city[2])
    
    # 주말 일과
    # vs 2019
    y_work_weekend_values_city_rate_vs2019.append(y_work_weekend_values_city[3]/y_work_weekend_values_city[1])
    # vs 2020
    y_work_weekend_values_city_rate_vs2020.append(y_work_weekend_values_city[3]/y_work_weekend_values_city[2])
    
    # 주말 퇴근
    # vs 2019
    y_back_weekend_values_city_rate_vs2019.append(y_back_weekend_values_city[3]/y_back_weekend_values_city[1])
    # vs 2020
    y_back_weekend_values_city_rate_vs2020.append(y_back_weekend_values_city[3]/y_back_weekend_values_city[2])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 0.4359456981140872

# %%
y_go_weekday_values_city_rate_vs2019
# Out:
# [0.4359456981140872]

# %%
DAGUCARD06_2019_before_weekday_start_list_gu=[]
DAGUCARD06_2019_before_weekend_start_list_gu=[]
DAGUCARD06_2019_after_weekday_start_list_gu=[]
DAGUCARD06_2019_after_weekend_start_list_gu=[]
DAGUCARD06_2020_before_weekday_start_list_gu=[]
DAGUCARD06_2020_before_weekend_start_list_gu=[]
DAGUCARD06_2020_after_weekday_start_list_gu=[]
DAGUCARD06_2020_after_weekend_start_list_gu=[]

DAGUCARD06_2019_before_weekday_arrival_list_gu=[]
DAGUCARD06_2019_before_weekend_arrival_list_gu=[]
DAGUCARD06_2019_after_weekday_arrival_list_gu=[]
DAGUCARD06_2019_after_weekend_arrival_list_gu=[]
DAGUCARD06_2020_before_weekday_arrival_list_gu=[]
DAGUCARD06_2020_before_weekend_arrival_list_gu=[]
DAGUCARD06_2020_after_weekday_arrival_list_gu=[]
DAGUCARD06_2020_after_weekend_arrival_list_gu=[]

DAGUCARD06_2019_before_weekday_list_gu=[]
DAGUCARD06_2019_before_weekend_list_gu=[]
DAGUCARD06_2019_after_weekday_list_gu=[]
DAGUCARD06_2019_after_weekend_list_gu=[]
DAGUCARD06_2020_before_weekday_list_gu=[]
DAGUCARD06_2020_before_weekend_list_gu=[]
DAGUCARD06_2020_after_weekday_list_gu=[]
DAGUCARD06_2020_after_weekend_list_gu=[]

# %%
# 출근_통행인원
def go_personnel_gu(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday_start = DAGUCARD06_2019_before_weekday_start_tmp.sum()
    DAGUCARD06_2019_before_weekday_start_list_gu.append(DAGUCARD06_2019_before_weekday_start/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend_start = DAGUCARD06_2019_before_weekend_start_tmp.sum()
    DAGUCARD06_2019_before_weekend_start_list_gu.append(DAGUCARD06_2019_before_weekend_start/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday_start = DAGUCARD06_2019_after_weekday_start_tmp.sum()
    DAGUCARD06_2019_after_weekday_start_list_gu.append(DAGUCARD06_2019_after_weekday_start/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend_start = DAGUCARD06_2019_after_weekend_start_tmp.sum()
    DAGUCARD06_2019_after_weekend_start_list_gu.append(DAGUCARD06_2019_after_weekend_start/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday_start = DAGUCARD06_2020_before_weekday_start_tmp.sum()
    DAGUCARD06_2020_before_weekday_start_list_gu.append(DAGUCARD06_2020_before_weekday_start/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend_start = DAGUCARD06_2020_before_weekend_start_tmp.sum()
    DAGUCARD06_2020_before_weekend_start_list_gu.append(DAGUCARD06_2020_before_weekend_start/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday_start = DAGUCARD06_2020_after_weekday_start_tmp.sum()
    DAGUCARD06_2020_after_weekday_start_list_gu.append(DAGUCARD06_2020_after_weekday_start/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend_start = DAGUCARD06_2020_after_weekend_start_tmp.sum()
    DAGUCARD06_2020_after_weekend_start_list_gu.append(DAGUCARD06_2020_after_weekend_start/14)

# %%
# 일과_통행인원
def work_personnel_gu(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday = DAGUCARD06_2019_before_weekday_tmp.sum()
    DAGUCARD06_2019_before_weekday_list_gu.append(DAGUCARD06_2019_before_weekday/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend = DAGUCARD06_2019_before_weekend_tmp.sum()
    DAGUCARD06_2019_before_weekend_list_gu.append(DAGUCARD06_2019_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday = DAGUCARD06_2019_after_weekday_tmp.sum()
    DAGUCARD06_2019_after_weekday_list_gu.append(DAGUCARD06_2019_after_weekday/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend = DAGUCARD06_2019_after_weekend_tmp.sum()
    DAGUCARD06_2019_after_weekend_list_gu.append(DAGUCARD06_2019_after_weekend/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday = DAGUCARD06_2020_before_weekday_tmp.sum()
    DAGUCARD06_2020_before_weekday_list_gu.append(DAGUCARD06_2020_before_weekday/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend = DAGUCARD06_2020_before_weekend_tmp.sum()
    DAGUCARD06_2020_before_weekend_list_gu.append(DAGUCARD06_2020_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday = DAGUCARD06_2020_after_weekday_tmp.sum()
    DAGUCARD06_2020_after_weekday_list_gu.append(DAGUCARD06_2020_after_weekday/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend = DAGUCARD06_2020_after_weekend_tmp.sum()
    DAGUCARD06_2020_after_weekend_list_gu.append(DAGUCARD06_2020_after_weekend/14)

# %%
# 퇴근_통행인원
def back_personnel_gu(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday_arrival = DAGUCARD06_2019_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekday_arrival_list_gu.append(DAGUCARD06_2019_before_weekday_arrival/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend_arrival = DAGUCARD06_2019_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekend_arrival_list_gu.append(DAGUCARD06_2019_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday_arrival = DAGUCARD06_2019_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekday_arrival_list_gu.append(DAGUCARD06_2019_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend_arrival = DAGUCARD06_2019_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekend_arrival_list_gu.append(DAGUCARD06_2019_after_weekend_arrival/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday_arrival = DAGUCARD06_2020_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekday_arrival_list_gu.append(DAGUCARD06_2020_before_weekday_arrival/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend_arrival = DAGUCARD06_2020_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekend_arrival_list_gu.append(DAGUCARD06_2020_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday_arrival = DAGUCARD06_2020_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekday_arrival_list_gu.append(DAGUCARD06_2020_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.시군구_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend_arrival = DAGUCARD06_2020_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekend_arrival_list_gu.append(DAGUCARD06_2020_after_weekend_arrival/14)

# %%
for i in gu_code_list:
    go_personnel_gu(i)
    work_personnel_gu(i)
    back_personnel_gu(i)

# %%
y_go_weekday_values_gu_rate_vs2020 = []
y_go_weekend_values_gu_rate_vs2020 = []
y_work_weekday_values_gu_rate_vs2020 = []
y_work_weekend_values_gu_rate_vs2020 = []
y_back_weekday_values_gu_rate_vs2020 = []
y_back_weekend_values_gu_rate_vs2020 = []
    
y_go_weekday_values_gu_rate_vs2019 = []
y_go_weekend_values_gu_rate_vs2019 = []
y_work_weekday_values_gu_rate_vs2019 = []
y_work_weekend_values_gu_rate_vs2019 = []
y_back_weekday_values_gu_rate_vs2019 = []
y_back_weekend_values_gu_rate_vs2019 = []

for i in range(len(gu_code_list)):


    
    y_go_weekday_values_gu = []
    y_go_weekend_values_gu = []
    y_work_weekday_values_gu = []
    y_work_weekend_values_gu = []
    y_back_weekday_values_gu = []
    y_back_weekend_values_gu = []
    
    

    # 평일 출근
    y_go_weekday_values_gu.append(DAGUCARD06_2019_before_weekday_start_list_gu[i])
    y_go_weekday_values_gu.append(DAGUCARD06_2019_after_weekday_start_list_gu[i])
    y_go_weekday_values_gu.append(DAGUCARD06_2020_before_weekday_start_list_gu[i])
    y_go_weekday_values_gu.append(DAGUCARD06_2020_after_weekday_start_list_gu[i])
    
    # 주말 출근
    y_go_weekend_values_gu.append(DAGUCARD06_2019_before_weekend_start_list_gu[i])
    y_go_weekend_values_gu.append(DAGUCARD06_2019_after_weekend_start_list_gu[i])
    y_go_weekend_values_gu.append(DAGUCARD06_2020_before_weekend_start_list_gu[i])
    y_go_weekend_values_gu.append(DAGUCARD06_2020_after_weekend_start_list_gu[i])
    
    # 평일 일과
    y_work_weekday_values_gu.append(DAGUCARD06_2019_before_weekday_list_gu[i])
    y_work_weekday_values_gu.append(DAGUCARD06_2019_after_weekday_list_gu[i])
    y_work_weekday_values_gu.append(DAGUCARD06_2020_before_weekday_list_gu[i])
    y_work_weekday_values_gu.append(DAGUCARD06_2020_after_weekday_list_gu[i])
    
    # 주말 일과
    y_work_weekend_values_gu.append(DAGUCARD06_2019_before_weekend_list_gu[i])
    y_work_weekend_values_gu.append(DAGUCARD06_2019_after_weekend_list_gu[i])
    y_work_weekend_values_gu.append(DAGUCARD06_2020_before_weekend_list_gu[i])
    y_work_weekend_values_gu.append(DAGUCARD06_2020_after_weekend_list_gu[i])
    
    # 평일 퇴근
    y_back_weekday_values_gu.append(DAGUCARD06_2019_before_weekday_arrival_list_gu[i])
    y_back_weekday_values_gu.append(DAGUCARD06_2019_after_weekday_arrival_list_gu[i])
    y_back_weekday_values_gu.append(DAGUCARD06_2020_before_weekday_arrival_list_gu[i])
    y_back_weekday_values_gu.append(DAGUCARD06_2020_after_weekday_arrival_list_gu[i])
    
    # 주말 퇴근
    y_back_weekend_values_gu.append(DAGUCARD06_2019_before_weekend_arrival_list_gu[i])
    y_back_weekend_values_gu.append(DAGUCARD06_2019_after_weekend_arrival_list_gu[i])
    y_back_weekend_values_gu.append(DAGUCARD06_2020_before_weekend_arrival_list_gu[i])
    y_back_weekend_values_gu.append(DAGUCARD06_2020_after_weekend_arrival_list_gu[i])
    
    figure, ((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows = 2, ncols = 3)
    figure.set_size_inches(24,20)
    
    label=['19.01.01~19.02.17','19.02.18~19.04.06','20.01.01~20.02.17','20.02.18~20.04.06']
    index=np.arange(len(label))
   
    
    # 평일 출근
    ax1.bar(index,y_go_weekday_values_gu)
    ax1.set_title('{} Weekday_go_to_work'.format(gu_code_list[i]))
    ax1.set_xticks([0,1,2,3])
    ax1.set_xticklabels(label)
    ax1.legend()
    
     # 평일 일과
    ax2.bar(index,y_work_weekday_values_gu)
    ax2.set_title('{} Weekday_work'.format(gu_code_list[i]))
    ax2.set_xticks([0,1,2,3])
    ax2.set_xticklabels(label)
    ax2.legend()
    
     # 평일 퇴근
    ax3.bar(index,y_back_weekday_values_gu)
    ax3.set_title('{} Weekday_off_work'.format(gu_code_list[i]))
    ax3.set_xticks([0,1,2,3])
    ax3.set_xticklabels(label)
    ax3.legend()
    
     # 주말 출근
    ax4.bar(index,y_go_weekend_values_gu)
    ax4.set_title('{} Weekend_go_to_work'.format(gu_code_list[i]))
    ax4.set_xticks([0,1,2,3])
    ax4.set_xticklabels(label)
    ax4.legend()
    
    # 주말 일과
    ax5.bar(index,y_work_weekend_values_gu)
    ax5.set_title('{} Weekend_work'.format(gu_code_list[i]))
    ax5.set_xticks([0,1,2,3])
    ax5.set_xticklabels(label)
    ax5.legend()    
   
    # 주말 퇴근
    ax6.bar(index,y_back_weekend_values_gu)
    ax6.set_title('{} Weekend_off_work'.format(gu_code_list[i]))
    ax6.set_xticks([0,1,2,3])
    ax6.set_xticklabels(label)
    ax6.legend()
 #   plt.savefig('{}_출근_일과_퇴근.png'.format(gu_code_list[i]))
    
     
    
    
    # 평일 출근 
    # vs 2019
    y_go_weekday_values_gu_rate_vs2019.append(y_go_weekday_values_gu[3]/y_go_weekday_values_gu[1])
    # vs 2020
    y_go_weekday_values_gu_rate_vs2020.append(y_go_weekday_values_gu[3]/y_go_weekday_values_gu[2])

    # 평일 일과
    # vs 2019
    y_work_weekday_values_gu_rate_vs2019.append(y_work_weekday_values_gu[3]/y_work_weekday_values_gu[1])
    # vs 2020
    y_work_weekday_values_gu_rate_vs2020.append(y_work_weekday_values_gu[3]/y_work_weekday_values_gu[2])
    
    # 평일 퇴근
    # vs 2019
    y_back_weekday_values_gu_rate_vs2019.append(y_back_weekday_values_gu[3]/y_back_weekday_values_gu[1])
    # vs 2020
    y_back_weekday_values_gu_rate_vs2020.append(y_back_weekday_values_gu[3]/y_back_weekday_values_gu[2])
    
    # 주말 출근
    # vs 2019
    y_go_weekend_values_gu_rate_vs2019.append(y_go_weekend_values_gu[3]/y_go_weekend_values_gu[1])
    # vs 2020
    y_go_weekend_values_gu_rate_vs2020.append(y_go_weekend_values_gu[3]/y_go_weekend_values_gu[2])
    
    # 주말 일과
    # vs 2019
    y_work_weekend_values_gu_rate_vs2019.append(y_work_weekend_values_gu[3]/y_work_weekend_values_gu[1])
    # vs 2020
    y_work_weekend_values_gu_rate_vs2020.append(y_work_weekend_values_gu[3]/y_work_weekend_values_gu[2])
    
    # 주말 퇴근
    # vs 2019
    y_back_weekend_values_gu_rate_vs2019.append(y_back_weekend_values_gu[3]/y_back_weekend_values_gu[1])
    # vs 2020
    y_back_weekend_values_gu_rate_vs2020.append(y_back_weekend_values_gu[3]/y_back_weekend_values_gu[2])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ...

# %%
# Out:
# 9

# %%
DAGUCARD06_2019_before_weekday_start_list_dong=[]
DAGUCARD06_2019_before_weekend_start_list_dong=[]
DAGUCARD06_2019_after_weekday_start_list_dong=[]
DAGUCARD06_2019_after_weekend_start_list_dong=[]
DAGUCARD06_2020_before_weekday_start_list_dong=[]
DAGUCARD06_2020_before_weekend_start_list_dong=[]
DAGUCARD06_2020_after_weekday_start_list_dong=[]
DAGUCARD06_2020_after_weekend_start_list_dong=[]

DAGUCARD06_2019_before_weekday_arrival_list_dong=[]
DAGUCARD06_2019_before_weekend_arrival_list_dong=[]
DAGUCARD06_2019_after_weekday_arrival_list_dong=[]
DAGUCARD06_2019_after_weekend_arrival_list_dong=[]
DAGUCARD06_2020_before_weekday_arrival_list_dong=[]
DAGUCARD06_2020_before_weekend_arrival_list_dong=[]
DAGUCARD06_2020_after_weekday_arrival_list_dong=[]
DAGUCARD06_2020_after_weekend_arrival_list_dong=[]

DAGUCARD06_2019_before_weekday_list_dong=[]
DAGUCARD06_2019_before_weekend_list_dong=[]
DAGUCARD06_2019_after_weekday_list_dong=[]
DAGUCARD06_2019_after_weekend_list_dong=[]
DAGUCARD06_2020_before_weekday_list_dong=[]
DAGUCARD06_2020_before_weekend_list_dong=[]
DAGUCARD06_2020_after_weekday_list_dong=[]
DAGUCARD06_2020_after_weekend_list_dong=[]

# %%
# 출근_통행인원
def go_personnel_dong(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday_start = DAGUCARD06_2019_before_weekday_start_tmp.sum()
    DAGUCARD06_2019_before_weekday_start_list_dong.append(DAGUCARD06_2019_before_weekday_start/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend_start = DAGUCARD06_2019_before_weekend_start_tmp.sum()
    DAGUCARD06_2019_before_weekend_start_list_dong.append(DAGUCARD06_2019_before_weekend_start/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday_start = DAGUCARD06_2019_after_weekday_start_tmp.sum()
    DAGUCARD06_2019_after_weekday_start_list_dong.append(DAGUCARD06_2019_after_weekday_start/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend_start = DAGUCARD06_2019_after_weekend_start_tmp.sum()
    DAGUCARD06_2019_after_weekend_start_list_dong.append(DAGUCARD06_2019_after_weekend_start/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday_start = DAGUCARD06_2020_before_weekday_start_tmp.sum()
    DAGUCARD06_2020_before_weekday_start_list_dong.append(DAGUCARD06_2020_before_weekday_start/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend_start = DAGUCARD06_2020_before_weekend_start_tmp.sum()
    DAGUCARD06_2020_before_weekend_start_list_dong.append(DAGUCARD06_2020_before_weekend_start/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday_start = DAGUCARD06_2020_after_weekday_start_tmp.sum()
    DAGUCARD06_2020_after_weekday_start_list_dong.append(DAGUCARD06_2020_after_weekday_start/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_start_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==7) | (DAGUCARD06.시간대==8))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend_start = DAGUCARD06_2020_after_weekend_start_tmp.sum()
    DAGUCARD06_2020_after_weekend_start_list_dong.append(DAGUCARD06_2020_after_weekend_start/14)

# %%
# 일과_통행인원
def work_personnel_dong(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday = DAGUCARD06_2019_before_weekday_tmp.sum()
    DAGUCARD06_2019_before_weekday_list_dong.append(DAGUCARD06_2019_before_weekday/34)
    # (주말)
    DAGUCARD06_2019_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend = DAGUCARD06_2019_before_weekend_tmp.sum()
    DAGUCARD06_2019_before_weekend_list_dong.append(DAGUCARD06_2019_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday = DAGUCARD06_2019_after_weekday_tmp.sum()
    DAGUCARD06_2019_after_weekday_list_dong.append(DAGUCARD06_2019_after_weekday/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend = DAGUCARD06_2019_after_weekend_tmp.sum()
    DAGUCARD06_2019_after_weekend_list_dong.append(DAGUCARD06_2019_after_weekend/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday = DAGUCARD06_2020_before_weekday_tmp.sum()
    DAGUCARD06_2020_before_weekday_list_dong.append(DAGUCARD06_2020_before_weekday/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend = DAGUCARD06_2020_before_weekend_tmp.sum()
    DAGUCARD06_2020_before_weekend_list_dong.append(DAGUCARD06_2020_before_weekend/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday = DAGUCARD06_2020_after_weekday_tmp.sum()
    DAGUCARD06_2020_after_weekday_list_dong.append(DAGUCARD06_2020_after_weekday/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==14) | (DAGUCARD06.시간대==15))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend = DAGUCARD06_2020_after_weekend_tmp.sum()
    DAGUCARD06_2020_after_weekend_list_dong.append(DAGUCARD06_2020_after_weekend/14)

# %%
# 퇴근_통행인원
def back_personnel_dong(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2019_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekday_arrival = DAGUCARD06_2019_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekday_arrival_list_dong.append(DAGUCARD06_2019_before_weekday_arrival/34)
    
    # (주말)
    DAGUCARD06_2019_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                              (DAGUCARD06.운행_일자 <=20190217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_before_weekend_arrival = DAGUCARD06_2019_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_before_weekend_arrival_list_dong.append(DAGUCARD06_2019_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2019_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekday_arrival = DAGUCARD06_2019_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekday_arrival_list_dong.append(DAGUCARD06_2019_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2019_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                              (DAGUCARD06.운행_일자 <=20190406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2019_after_weekend_arrival = DAGUCARD06_2019_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2019_after_weekend_arrival_list_dong.append(DAGUCARD06_2019_after_weekend_arrival/13)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (평일)
    DAGUCARD06_2020_before_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekday_arrival = DAGUCARD06_2020_before_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekday_arrival_list_dong.append(DAGUCARD06_2020_before_weekday_arrival/34)
    # (주말)
    DAGUCARD06_2020_before_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                              (DAGUCARD06.운행_일자 <=20200217) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_before_weekend_arrival = DAGUCARD06_2020_before_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_before_weekend_arrival_list_dong.append(DAGUCARD06_2020_before_weekend_arrival/14)
    
    # 02.18 ~ 04.06
    # (평일)
    DAGUCARD06_2020_after_weekday_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분!=1)&(DAGUCARD06.요일_구분!=7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekday_arrival = DAGUCARD06_2020_after_weekday_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekday_arrival_list_dong.append(DAGUCARD06_2020_after_weekday_arrival/35)
    # (주말)
    DAGUCARD06_2020_after_weekend_arrival_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                              (DAGUCARD06.운행_일자 <=20200406) & 
                                                              (DAGUCARD06.이용_지역_코드==dong_code)&
                                                              ((DAGUCARD06.요일_구분==1)|(DAGUCARD06.요일_구분==7))&
                                                              ((DAGUCARD06.시간대==17) | (DAGUCARD06.시간대==18))
                                                             ].발생_통행인원
    DAGUCARD06_2020_after_weekend_arrival = DAGUCARD06_2020_after_weekend_arrival_tmp.sum()
    DAGUCARD06_2020_after_weekend_arrival_list_dong.append(DAGUCARD06_2020_after_weekend_arrival/14)

# %%
for i in dong_code_list:
    go_personnel_dong(i)
    work_personnel_dong(i)
    back_personnel_dong(i)

# %%
y_go_weekday_values_dong_rate_vs2020 = []
y_go_weekend_values_dong_rate_vs2020 = []
y_work_weekday_values_dong_rate_vs2020 = []
y_work_weekend_values_dong_rate_vs2020 = []
y_back_weekday_values_dong_rate_vs2020 = []
y_back_weekend_values_dong_rate_vs2020 = []
   
y_go_weekday_values_dong_rate_vs2019 = []
y_go_weekend_values_dong_rate_vs2019 = []
y_work_weekday_values_dong_rate_vs2019 = []
y_work_weekend_values_dong_rate_vs2019 = []
y_back_weekday_values_dong_rate_vs2019 = []
y_back_weekend_values_dong_rate_vs2019 = []

for i in range(len(dong_code_list)):


    
    y_go_weekday_values_dong = []
    y_go_weekend_values_dong = []
    y_work_weekday_values_dong = []
    y_work_weekend_values_dong = []
    y_back_weekday_values_dong = []
    y_back_weekend_values_dong = []
    
    

    # 평일 출근
    y_go_weekday_values_dong.append(DAGUCARD06_2019_before_weekday_start_list_dong[i])
    y_go_weekday_values_dong.append(DAGUCARD06_2019_after_weekday_start_list_dong[i])
    y_go_weekday_values_dong.append(DAGUCARD06_2020_before_weekday_start_list_dong[i])
    y_go_weekday_values_dong.append(DAGUCARD06_2020_after_weekday_start_list_dong[i])
    
    # 주말 출근
    y_go_weekend_values_dong.append(DAGUCARD06_2019_before_weekend_start_list_dong[i])
    y_go_weekend_values_dong.append(DAGUCARD06_2019_after_weekend_start_list_dong[i])
    y_go_weekend_values_dong.append(DAGUCARD06_2020_before_weekend_start_list_dong[i])
    y_go_weekend_values_dong.append(DAGUCARD06_2020_after_weekend_start_list_dong[i])
    
    # 평일 일과
    y_work_weekday_values_dong.append(DAGUCARD06_2019_before_weekday_list_dong[i])
    y_work_weekday_values_dong.append(DAGUCARD06_2019_after_weekday_list_dong[i])
    y_work_weekday_values_dong.append(DAGUCARD06_2020_before_weekday_list_dong[i])
    y_work_weekday_values_dong.append(DAGUCARD06_2020_after_weekday_list_dong[i])
    
    # 주말 일과
    y_work_weekend_values_dong.append(DAGUCARD06_2019_before_weekend_list_dong[i])
    y_work_weekend_values_dong.append(DAGUCARD06_2019_after_weekend_list_dong[i])
    y_work_weekend_values_dong.append(DAGUCARD06_2020_before_weekend_list_dong[i])
    y_work_weekend_values_dong.append(DAGUCARD06_2020_after_weekend_list_dong[i])
    
    # 평일 퇴근
    y_back_weekday_values_dong.append(DAGUCARD06_2019_before_weekday_arrival_list_dong[i])
    y_back_weekday_values_dong.append(DAGUCARD06_2019_after_weekday_arrival_list_dong[i])
    y_back_weekday_values_dong.append(DAGUCARD06_2020_before_weekday_arrival_list_dong[i])
    y_back_weekday_values_dong.append(DAGUCARD06_2020_after_weekday_arrival_list_dong[i])
    
    # 주말 퇴근
    y_back_weekend_values_dong.append(DAGUCARD06_2019_before_weekend_arrival_list_dong[i])
    y_back_weekend_values_dong.append(DAGUCARD06_2019_after_weekend_arrival_list_dong[i])
    y_back_weekend_values_dong.append(DAGUCARD06_2020_before_weekend_arrival_list_dong[i])
    y_back_weekend_values_dong.append(DAGUCARD06_2020_after_weekend_arrival_list_dong[i])
    
    figure, ((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows = 2, ncols = 3)
    figure.set_size_inches(24,20)
    
    label=['19.01.01~19.02.17','19.02.18~19.04.06','20.01.01~20.02.17','20.02.18~20.04.06']
    index=np.arange(len(label))
   
    
    # 평일 출근
    ax1.bar(index,y_go_weekday_values_dong)
    ax1.set_title('{} Weekday_go_to_work'.format(dong_code_list[i]))
    ax1.set_xticks([0,1,2,3])
    ax1.set_xticklabels(label)
    ax1.legend()
    
     # 평일 일과
    ax2.bar(index,y_work_weekday_values_dong)
    ax2.set_title('{} Weekday_work'.format(dong_code_list[i]))
    ax2.set_xticks([0,1,2,3])
    ax2.set_xticklabels(label)
    ax2.legend()
    
     # 평일 퇴근
    ax3.bar(index,y_back_weekday_values_dong)
    ax3.set_title('{} Weekday_off_work'.format(dong_code_list[i]))
    ax3.set_xticks([0,1,2,3])
    ax3.set_xticklabels(label)
    ax3.legend()
    
     # 주말 출근
    ax4.bar(index,y_go_weekend_values_dong)
    ax4.set_title('{} Weekend_go_to_work'.format(dong_code_list[i]))
    ax4.set_xticks([0,1,2,3])
    ax4.set_xticklabels(label)
    ax4.legend()
    
    # 주말 일과
    ax5.bar(index,y_work_weekend_values_dong)
    ax5.set_title('{} Weekend_work'.format(dong_code_list[i]))
    ax5.set_xticks([0,1,2,3])
    ax5.set_xticklabels(label)
    ax5.legend()    
   
    # 주말 퇴근
    ax6.bar(index,y_back_weekend_values_dong)
    ax6.set_title('{} Weekend_off_work'.format(dong_code_list[i]))
    ax6.set_xticks([0,1,2,3])
    ax6.set_xticklabels(label)
    ax6.legend()
   # plt.savefig('{}_출근_일과_퇴근.png'.format(dong_code_list[i]))
    
    
    
    
    # 평일 출근 
    # vs 2019
    y_go_weekday_values_dong_rate_vs2019.append(y_go_weekday_values_dong[3]/y_go_weekday_values_dong[1])
    # vs 2020
    y_go_weekday_values_dong_rate_vs2020.append(y_go_weekday_values_dong[3]/y_go_weekday_values_dong[2])

    # 평일 일과
    # vs 2019
    y_work_weekday_values_dong_rate_vs2019.append(y_work_weekday_values_dong[3]/y_work_weekday_values_dong[1])
    # vs 2020
    y_work_weekday_values_dong_rate_vs2020.append(y_work_weekday_values_dong[3]/y_work_weekday_values_dong[2])
    
    # 평일 퇴근
    # vs 2019
    y_back_weekday_values_dong_rate_vs2019.append(y_back_weekday_values_dong[3]/y_back_weekday_values_dong[1])
    # vs 2020
    y_back_weekday_values_dong_rate_vs2020.append(y_back_weekday_values_dong[3]/y_back_weekday_values_dong[2])
    
    # 주말 출근
    # vs 2019
    y_go_weekend_values_dong_rate_vs2019.append(y_go_weekend_values_dong[3]/y_go_weekend_values_dong[1])
    # vs 2020
    y_go_weekend_values_dong_rate_vs2020.append(y_go_weekend_values_dong[3]/y_go_weekend_values_dong[2])
    
    # 주말 일과
    # vs 2019
    y_work_weekend_values_dong_rate_vs2019.append(y_work_weekend_values_dong[3]/y_work_weekend_values_dong[1])
    # vs 2020
    y_work_weekend_values_dong_rate_vs2020.append(y_work_weekend_values_dong[3]/y_work_weekend_values_dong[2])
    
    # 주말 퇴근
    # vs 2019
    y_back_weekend_values_dong_rate_vs2019.append(y_back_weekend_values_dong[3]/y_back_weekend_values_dong[1])
    # vs 2020
    y_back_weekend_values_dong_rate_vs2020.append(y_back_weekend_values_dong[3]/y_back_weekend_values_dong[2])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ...

# %%
len(y_work_weekday_values_dong_rate_vs2019)
# Out:
# 1

# %%
import csv
new_csv_header_list=['이용_지역_코드',
                     '평일_출근_작년','평일_일과_작년','평일_퇴근_작년',
                     '주말_출근_작년','주말_일과_작년','주말_퇴근_작년',
                     '평일_출근_올해','평일_일과_올해','평일_퇴근_올해',
                     '주말_출근_올해','주말_일과_올해','주말_퇴근_올해']
f=open("통행인원변화율.csv",'w')
writer = csv.writer(f, lineterminator='\n') # 줄 바꿈 코드(\n)을 지정
writer.writerow(new_csv_header_list) # list가 1차원 배열의 경우
for i in range(len(city_code_list)):
    tmp_list=[]
    tmp_list.append(city_code_list[i])
    tmp_list.append(y_go_weekday_values_city_rate_vs2019[i])
    tmp_list.append(y_work_weekday_values_city_rate_vs2019[i])
    tmp_list.append(y_back_weekday_values_city_rate_vs2019[i])
    
    tmp_list.append(y_go_weekend_values_city_rate_vs2019[i])
    tmp_list.append(y_work_weekend_values_city_rate_vs2019[i])
    tmp_list.append(y_back_weekend_values_city_rate_vs2019[i])
    
    tmp_list.append(y_go_weekday_values_city_rate_vs2020[i])
    tmp_list.append(y_work_weekday_values_city_rate_vs2020[i])
    tmp_list.append(y_back_weekday_values_city_rate_vs2020[i])
    
    tmp_list.append(y_go_weekend_values_city_rate_vs2020[i])
    tmp_list.append(y_work_weekend_values_city_rate_vs2020[i])
    tmp_list.append(y_back_weekend_values_city_rate_vs2020[i])
    writer.writerow(tmp_list)
for i in range(len(gu_code_list)):
    tmp_list=[]
    tmp_list.append(gu_code_list[i])
    tmp_list.append(y_go_weekday_values_gu_rate_vs2019[i])
    tmp_list.append(y_work_weekday_values_gu_rate_vs2019[i])
    tmp_list.append(y_back_weekday_values_gu_rate_vs2019[i])
    
    tmp_list.append(y_go_weekend_values_gu_rate_vs2019[i])
    tmp_list.append(y_work_weekend_values_gu_rate_vs2019[i])
    tmp_list.append(y_back_weekend_values_gu_rate_vs2019[i])
    
    tmp_list.append(y_go_weekday_values_gu_rate_vs2020[i])
    tmp_list.append(y_work_weekday_values_gu_rate_vs2020[i])
    tmp_list.append(y_back_weekday_values_gu_rate_vs2020[i])
    
    tmp_list.append(y_go_weekend_values_gu_rate_vs2020[i])
    tmp_list.append(y_work_weekend_values_gu_rate_vs2020[i])
    tmp_list.append(y_back_weekend_values_gu_rate_vs2020[i])
    writer.writerow(tmp_list)
for i in range(len(dong_code_list)):
    tmp_list=[]
    tmp_list.append(dong_code_list[i])
    tmp_list.append(y_go_weekday_values_dong_rate_vs2019[i])
    tmp_list.append(y_work_weekday_values_dong_rate_vs2019[i])
    tmp_list.append(y_back_weekday_values_dong_rate_vs2019[i])
    
    tmp_list.append(y_go_weekend_values_dong_rate_vs2019[i])
    tmp_list.append(y_work_weekend_values_dong_rate_vs2019[i])
    tmp_list.append(y_back_weekend_values_dong_rate_vs2019[i])
    
    tmp_list.append(y_go_weekday_values_dong_rate_vs2020[i])
    tmp_list.append(y_work_weekday_values_dong_rate_vs2020[i])
    tmp_list.append(y_back_weekday_values_dong_rate_vs2020[i])
    
    tmp_list.append(y_go_weekend_values_dong_rate_vs2020[i])
    tmp_list.append(y_work_weekend_values_dong_rate_vs2020[i])
    tmp_list.append(y_back_weekend_values_dong_rate_vs2020[i])
    writer.writerow(tmp_list)

f.close()

# %%
for i in range(len(dong_code_list)):
    tmp_list=[]
    tmp_list.append(dong_code_list)
    tmp_list.append(y_go_weekday_values_dong_rate_vs2019[i])
    tmp_list.append(y_work_weekday_values_dong_rate_vs2019[i])
    tmp_list.append(y_back_weekday_values_dong_rate_vs2019[i])
    
    tmp_list.append(y_go_weekdend_values_dong_rate_vs2019[i])
    tmp_list.append(y_work_weekend_values_dong_rate_vs2019[i])
    tmp_list.append(y_back_weekend_values_dong_rate_vs2019[i])
    
    tmp_list.append(y_go_weekday_values_dong_rate_vs2020[i])
    tmp_list.append(y_work_weekday_values_dong_rate_vs2020[i])
    tmp_list.append(y_back_weekday_values_dong_rate_vs2020[i])
    
    tmp_list.append(y_go_weekdend_values_dong_rate_vs2020[i])
    tmp_list.append(y_work_weekend_values_dong_rate_vs2020[i])
    tmp_list.append(y_back_weekend_values_dong_rate_vs2020[i])
    
    
  
    data=print(tmp_list)
# Out:
# [0.520125786163522, 0.4026845637583893, 0.3799795501022495, 0.28831635710005993, 0.542352451481989, 0.3770825384713214, 0.3918812193966198, 0.3374818660762007, 0.38962163263227584, 0.25585694653491264, 0.448778940691405, 0.30652574991252346]

# %%
DAGUCARD06_2019_before_bus_list_city=[]
DAGUCARD06_2019_before_train_list_city=[]
DAGUCARD06_2019_after_bus_list_city=[]
DAGUCARD06_2019_after_train_list_city=[]

DAGUCARD06_2020_before_bus_list_city=[]
DAGUCARD06_2020_before_train_list_city=[]
DAGUCARD06_2020_after_bus_list_city=[]
DAGUCARD06_2020_after_train_list_city=[]

# %%
 DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &(DAGUCARD06.운행_일자 <=20200217) &(DAGUCARD06.교통수단_코드 ==11)].발생_통행인원
# Out:
# 26177406    0
# 26177407    0
# 26177408    0
# 26177409    0
# 26177410    0
#            ..
# 34791429    1
# 34791430    0
# 34791431    0
# 34791432    1
# 34791433    1
# Name: 발생_통행인원, Length: 464347, dtype: int64

# %%
# 일과_통행인원
def bus_train_gu(dong_code):
    # 2019년
    # 01.01 ~ 02.17 
    # (버스)
    DAGUCARD06_2019_before_bus_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                    (DAGUCARD06.운행_일자 <=20190217) &
                                                    (DAGUCARD06.시도_코드==dong_code)&
                                                    (DAGUCARD06.교통수단_코드 ==1)
                                                   ].발생_통행인원                                                          
    DAGUCARD06_2019_before_bus = DAGUCARD06_2019_before_bus_tmp.sum()
    DAGUCARD06_2019_before_bus_list_city.append(DAGUCARD06_2019_before_bus)
    # (지하털)
    DAGUCARD06_2019_before_train_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190101) &
                                                      (DAGUCARD06.운행_일자 <=20190217) & 
                                                      (DAGUCARD06.시도_코드==dong_code)&
                                                      (DAGUCARD06.교통수단_코드 ==11)].발생_통행인원                                                            
    DAGUCARD06_2019_before_train = DAGUCARD06_2019_before_train_tmp.sum()
    DAGUCARD06_2019_before_train_list_city.append(DAGUCARD06_2019_before_train)
    
    # 02.18 ~ 04.06 
    # (버스)
    DAGUCARD06_2019_after_bus_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                   (DAGUCARD06.운행_일자 <=20190406) & 
                                                   (DAGUCARD06.시도_코드==dong_code) &
                                                   (DAGUCARD06.교통수단_코드 ==1)].발생_통행인원                                                            
    DAGUCARD06_2019_after_bus = DAGUCARD06_2019_after_bus_tmp.sum()
    DAGUCARD06_2019_after_bus_list_city.append(DAGUCARD06_2019_after_bus)
    # (지하털)
    DAGUCARD06_2019_after_train_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20190218) &
                                                     (DAGUCARD06.운행_일자 <=20190406) & 
                                                     (DAGUCARD06.시도_코드==dong_code) &
                                                     (DAGUCARD06.교통수단_코드 ==11)].발생_통행인원                                                            
    DAGUCARD06_2019_after_train = DAGUCARD06_2019_after_train_tmp.sum()
    DAGUCARD06_2019_after_train_list_city.append(DAGUCARD06_2019_after_train)
    
    
    # 2020년
    # 01.01 ~ 02.17 
    # (버스)
    DAGUCARD06_2020_before_bus_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                    (DAGUCARD06.운행_일자 <=20200217) & 
                                                    (DAGUCARD06.시도_코드==dong_code)&
                                                    (DAGUCARD06.교통수단_코드 ==1)].발생_통행인원                                                            
    DAGUCARD06_2020_before_bus = DAGUCARD06_2020_before_bus_tmp.sum()
    DAGUCARD06_2020_before_bus_list_city.append(DAGUCARD06_2020_before_bus)
    # (지하털)
    DAGUCARD06_2020_before_train_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200101) &
                                                      (DAGUCARD06.운행_일자 <=20200217) & 
                                                      (DAGUCARD06.시도_코드==dong_code)&
                                                      (DAGUCARD06.교통수단_코드 ==11)].발생_통행인원                                                            
    DAGUCARD06_2020_before_train = DAGUCARD06_2020_before_train_tmp.sum()
    DAGUCARD06_2020_before_train_list_city.append(DAGUCARD06_2020_before_train)
    
    # 02.18 ~ 04.06 
    # (버스)
    DAGUCARD06_2020_after_bus_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                   (DAGUCARD06.운행_일자 <=20200406) & 
                                                   (DAGUCARD06.시도_코드==dong_code) &
                                                   (DAGUCARD06.교통수단_코드 ==1)].발생_통행인원                                                            
    DAGUCARD06_2020_after_bus = DAGUCARD06_2020_after_bus_tmp.sum()
    DAGUCARD06_2020_after_bus_list_city.append(DAGUCARD06_2020_after_bus)
    # (지하털)
    DAGUCARD06_2020_after_train_tmp = DAGUCARD06.loc[(DAGUCARD06.운행_일자 >=20200218) &
                                                     (DAGUCARD06.운행_일자 <=20200406) & 
                                                     (DAGUCARD06.시도_코드==dong_code) &
                                                     (DAGUCARD06.교통수단_코드 ==11)].발생_통행인원                                                            
    DAGUCARD06_2020_after_train = DAGUCARD06_2020_after_train_tmp.sum()
    DAGUCARD06_2020_after_train_list_city.append(DAGUCARD06_2020_after_train)

# %%
for i in city_code_list:
    bus_train_gu(i)

# %%
DAGUCARD06_2020_after_train_list_city[0]
# Out:
# 18549426

# %%
for i in range(len(city_code_list)):

    y_bus_values_city = []
    y_train_values_city = []
    
    y_bus_values_city.append(DAGUCARD06_2019_before_bus_list_city[i])
    y_bus_values_city.append(DAGUCARD06_2019_after_bus_list_city[i])
    y_bus_values_city.append(DAGUCARD06_2020_before_bus_list_city[i])
    y_bus_values_city.append(DAGUCARD06_2020_after_bus_list_city[i])

    y_train_values_city.append(DAGUCARD06_2019_before_train_list_city[i])
    y_train_values_city.append(DAGUCARD06_2019_after_train_list_city[i])
    y_train_values_city.append(DAGUCARD06_2020_before_train_list_city[i])
    y_train_values_city.append(DAGUCARD06_2020_after_train_list_city[i])
    
    
    figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2)
    figure.set_size_inches(24,20)
    
    label=['19.01.01~19.02.17','19.02.18~19.04.06','20.01.01~20.02.17','20.02.18~20.04.06']
    index=np.arange(len(label))
   
    
    # 평일 출근
    ax1.bar(index,y_bus_values_city)
    ax1.set_title('{} bus'.format(city_code_list[i]))
    ax1.set_xticks([0,1,2,3])
    ax1.set_xticklabels(label)
    ax1.legend()
    
     # 평일 일과
    ax2.bar(index,y_train_values_city)
    ax2.set_title('{} train'.format(city_code_list[i]))
    ax2.set_xticks([0,1,2,3])
    ax2.set_xticklabels(label)
    ax2.legend()
    
    plt.savefig('{}_bus_train.png'.format(city_code_list[i]))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
